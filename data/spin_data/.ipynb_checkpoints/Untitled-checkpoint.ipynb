# %%
import numpy as np

# %%
data = np.load('test.npz', mmap_mode='r')

# %%
data.files
# Out:
# ['X_test', 'Y_test']

# %%
X = data['X_test'][:50]
Y = data['Y_test'][:50]

# %%
X.shape
# Out:
# (50, 10, 1, 256, 256)

# %%
Y.shape
# Out:
# (50, 90, 1, 256, 256)

# %%
np.savez('test_50sequences.npz', X_test=X,Y_test=Y)

# %%
data = np.load('test_50sequences.npz', mmap_mode='r')

# %%
data.files
# Out:
# ['X_test', 'Y_test']

# %%
data['X_test'].shape
# Out:
# (50, 10, 1, 256, 256)

# %%
data = np.load('valid.npz', mmap_mode='r')
data['X_val'].shape
# Out:
# (159, 10, 1, 64, 64)

# %%
data = np.load('../../work_dirs/spin_simvp_output256x256/saved/preds.npy')

# %%
data.shape
# Out:
# (50, 90, 1, 256, 256)
